# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from glob import glob
from os import getcwd, path as base_path
from tqdm import tqdm
import re

import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from spacy import displacy

# %%
from sys import path
PROJECT_PATH = getcwd()[:getcwd().find("notebooks")][:-1]
path.append(f"{PROJECT_PATH}\\src")

# %%
from utils import (get_words_contractions, 
                   find_urls_in_text, 
                   get_stopwords)

# %%
PROJECT_NAME = "wsj_tweet_scrapping"
PROJECT_PATH = getcwd()[: getcwd().find(PROJECT_NAME) + len(PROJECT_NAME)]
DATA_PATH = f"{PROJECT_PATH}\\data"
EXCEL_PATH = f"{DATA_PATH}\\excel"

FILE_FORMAT = "twint_wsj_logistics_news_"

# %%
news_files = glob(f"{EXCEL_PATH}\\*.xlsx")
news_files = [file_ for file_ in news_files if FILE_FORMAT in base_path.basename(file_)]

# %%
all_data = []
for i in tqdm(range(len(news_files))): 
    content = pd.read_excel(news_files[i])
    for val in content.values[:, :6]:
        all_data.append(val)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 94/94 [00:01<00:00, 50.06it/s]

# %%
cols = pd.read_excel(news_files[0]).columns
news_df = pd.DataFrame(all_data, columns=cols)
news_df = news_df.sort_values("date").reset_index(drop=True) 
news_df.head()
# Out:
#          data-item-id  data-conversation-id        date  \
# 0  138783141312741408    138783141312741408  2011-11-21
# 1  138950373275738096    138950373275738096  2011-11-22
# 2  139191305766055904    139191305766055904  2011-11-22
# 3  138978095397998592    138978095397998592  2011-11-22
# 4  138931945504636896    138931945504636896  2011-11-22
#
#                                                tweet  \
# 0    Chinese Media Firm Hit by Muddy Waters on.ws...
# 1    China Pushes Clean-Energy Agenda on.wsj.com/...
# 2    PCCW Prices Telecom Trust IPO at Low End on....
# 3    Solar Companies Swing to Loss on.wsj.com/sH5...
# 4    China Doubles Size of Hong Kong Currency Swa...
#
#                         url                                               text
# 0  http://on.wsj.com/vMZ1s2  Focus Media Holding Ltd. lashed back Tuesday a...
# 1  http://on.wsj.com/ty6fGV  BEIJING—China plans to push for more funding f...
# 2  http://on.wsj.com/sP81tk  HONG KONG—Fixed-line telecom operator PCCW Ltd...
# 3  http://on.wsj.com/sH5ICa  Chinese solar-products companies JA Solar Hold...
# 4  http://on.wsj.com/uza2y6  SHANGHAI—China and Hong Kong said Tuesday they...

# %%
def clean_news(news, 
               remove_stopwords : bool = False, 
               process_contractions : bool = False, 
               remove_special_chars : bool = False,
               remove_all_special_chars : bool = False,
               remove_single_alpha_char_word : bool = False):
    
    urls_to_remove = find_urls_in_text(news)
    
    remove_texts = ["Sign up: With one click, get this newsletter "
                    "delivered to your inbox.",
                    "News and analysis on the world of logistics, "
                    "from supply chain to transport and technology. "
                    "Trouble viewing this email? View in web browser", 
                   "Write to him at paul.page@wsj.com. "
                    "Follow the WSJ Logistics Report team: @PaulPage, "
                    "@jensmithWSJ, @EEPhillips_WSJ, @CostasParis. "
                    "Follow the WSJ Logistics Report on Twitter at @WSJLogistics."
                   ]
    
    for text in remove_texts:
        news = news.replace(text, " ")
        
    for url in urls_to_remove:
        news = news.replace(url, " ")

    news = news.lower()

    if process_contractions:
        cleaned_news = ""
        contractions = get_words_contractions()
        for word in news.split():
            if word in contractions:
                word = contractions[word]
            cleaned_news += " " + word
        news = cleaned_news
        
    if remove_stopwords:
        cleaned_news = ""
        stopwords = get_stopwords(lang="english")
        for word in news.split():
            if word not in stopwords:
                cleaned_news += " " + word
        news = cleaned_news
         
    if remove_special_chars:
        if remove_all_special_chars:
            chars_to_keep = "abcdefghijklmnopqrstuvwxyz1234567890 "
        else:
            chars_to_keep = "abcdefghijklmnopqrstuvwxyz1234567890 .,''’"
        news = "".join([char_ if char_ in chars_to_keep else " " for char_ in news])
    
    if remove_single_alpha_char_word:
        cleaned_news = ""
        for word in news.split():
            if word.isdigit() or len(word) > 1:
                cleaned_news += " " + word
        news = cleaned_news

    news = " ".join(news.split())     

    return news

# %%
clean_news_text = news_df["text"].apply(lambda x: clean_news(str(x),
                                                             process_contractions = True, 
                                                             remove_stopwords = True))

# %%
news_df["clean_news_text"] = clean_news_text

# %%
news_df.head()
# Out:
#          data-item-id  data-conversation-id        date  \
# 0  138783141312741408    138783141312741408  2011-11-21
# 1  138950373275738096    138950373275738096  2011-11-22
# 2  139191305766055904    139191305766055904  2011-11-22
# 3  138978095397998592    138978095397998592  2011-11-22
# 4  138931945504636896    138931945504636896  2011-11-22
#
#                                                tweet  \
# 0    Chinese Media Firm Hit by Muddy Waters on.ws...
# 1    China Pushes Clean-Energy Agenda on.wsj.com/...
# 2    PCCW Prices Telecom Trust IPO at Low End on....
# 3    Solar Companies Swing to Loss on.wsj.com/sH5...
# 4    China Doubles Size of Hong Kong Currency Swa...
#
#                         url  \
# 0  http://on.wsj.com/vMZ1s2
# 1  http://on.wsj.com/ty6fGV
# 2  http://on.wsj.com/sP81tk
# 3  http://on.wsj.com/sH5ICa
# 4  http://on.wsj.com/uza2y6
#
#                                                 text  \
# 0  Focus Media Holding Ltd. lashed back Tuesday a...
# 1  BEIJING—China plans to push for more funding f...
# 2  HONG KONG—Fixed-line telecom operator PCCW Ltd...
# 3  Chinese solar-products companies JA Solar Hold...
# 4  SHANGHAI—China and Hong Kong said Tuesday they...
#
#                                      clean_news_text
# 0  focus media holding ltd. lashed back tuesday m...
# 1  beijing—china plans push funding clean-energy ...
# 2  hong kong—fixed-line telecom operator pccw ltd...
# 3  chinese solar-products companies ja solar hold...
# 4  shanghai—china hong kong said tuesday doubled ...

# %%
news_df.to_excel(f"{EXCEL_PATH}\\"
                 f"wsj_logistics_news_{min(pd.to_datetime(news_df['date']).dt.date).year}"
                 f"-{max(pd.to_datetime(news_df['date']).dt.date).year}.xlsx", index=False)

# %%
news_df.iloc[100]["text"][:600]
# Out:
# "TOKYO—Las Vegas Sands Corp. Chief Executive Sheldon Adelson offered his views on the fight between Steve Wynn and his former Japanese partner, suggesting that Mr. Adelson's Las Vegas casino rival may have gone too far in ousting co-founder Kazuo Okada from Wynn Resorts Ltd. Asked to comment on allegations at the heart of dispute, Mr. Adelson said offering complimentary hotel rooms is common practice in the gambling industry. Wynn Resorts has said Mr. Okada's alleged attempts to win favors through such offers was illegal and... WSJ Membership Customer Service Tools & Features Ads More Dow Jones"

# %%
news_df.iloc[100]["clean_news_text"][:600]
# Out:
# "tokyo—las vegas sands corp. chief executive sheldon adelson offered views fight steve wynn former japanese partner, suggesting mr. adelson's las vegas casino rival may gone far ousting co-founder kazuo okada wynn resorts ltd. asked comment allegations heart dispute, mr. adelson said offering complimentary hotel rooms common practice gambling industry. wynn resorts said mr. okada's alleged attempts win favors offers illegal and... wsj membership customer service tools & features ads dow jones products"

# %%
# news_df.to_excel(f"{EXCEL_PATH}\\wsj-news-2019-2020.xlsx", index=False)

# %%
##

# %%
nlp = en_core_web_sm.load()

# %%
doc = nlp(news_df.iloc[100]["text"])
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('the first quarter', 'DATE'), ('the WSJ Logistics Report', 'ORG'), ('Costas', 'NORP'), ('Paris', 'GPE'), ('35%', 'PERCENT'), ('the first quarter from a year ago', 'DATE'), ('Australia', 'GPE'), ('Latin America', 'LOC'), ('China', 'GPE'), ('this year', 'DATE'), ('Brazil', 'GPE'), ('Vale S.A.’s', 'ORG'), ('JD.com', 'PERSON'), ('Chinese', 'NORP'), ('WSJ', 'ORG'), ('Shan Li', 'PERSON'), ('China', 'GPE'), ('JD.com', 'PERSON'), ('2', 'CARDINAL'), ('Alibaba Group Holding Ltd.', 'ORG'), ('China', 'GPE'), ('recent weeks', 'DATE'), ('more than 550', 'CARDINAL'), ('China', 'GPE'), ('the Nippon Steel & Sumitomo Metal Corp.', 'ORG'), ('Kashima', 'GPE'), ('Japan', 'GPE'), ('iPhone', 'ORG'), ('Asia', 'LOC'), ('Taiwan', 'GPE'), ('China', 'GPE'), ('Japanese', 'NORP'), ('Apple Inc.', 'ORG'), ('WSJ', 'ORG'), ('Takashi Mochizuki', 'PERSON'), ('Japan Display Inc.', 'ORG'), ('Japan', 'GPE'), ('Taiwanese', 'NORP'), ('TPK Holding Co.', 'ORG'), ('Japan', 'GPE'), ('Japan', 'GPE'), ('China', 'GPE'), ('Beijing', 'GPE'), ('U.S.', 'GPE'), ('Russian', 'NORP'), ('United Co.', 'ORG'), ('Rusal', 'PERSON'), ('$200 million', 'MONEY'), ('Kentucky', 'GPE'), ('U.S.', 'GPE'), ('nearly four decades', 'DATE'), ('WSJ', 'ORG'), ('Bob Tita', 'PERSON'), ('Braidy Industries', 'ORG'), ('next year', 'DATE'), ('Ashland', 'GPE'), ('Ky.', 'GPE'), ('Trump', 'ORG'), ('10%', 'PERCENT'), ('last year', 'DATE'), ('U.S.', 'GPE'), ('one', 'CARDINAL'), ('U.S.', 'GPE'), ('JD', 'ORG'), ('Year-over-year', 'DATE'), ('Los Angeles', 'GPE'), ('Long Beach', 'GPE'), ('March', 'DATE'), ('U.S.', 'GPE'), ('April', 'DATE'), ('WSJ', 'ORG'), ('The European Union', 'ORG'), ('$12 billion', 'MONEY'), ('U.S.', 'GPE'), ('Boeing Co.', 'ORG'), ('WSJ', 'ORG'), ('India', 'GPE'), ('Jet Airways', 'ORG'), ('WSJ', 'ORG'), ('Bristol-Myers Squibb', 'ORG'), ('$74 billion', 'MONEY'), ('Celgene Corp.', 'ORG'), ('WSJ', 'ORG'), ('Merck KGaA', 'ORG'), ('Versum Materials Inc.', 'ORG'), ('WSJ', 'ORG'), ('Foxconn Technology Group', 'ORG'), ('Terry Gou', 'PERSON'), ('iPhone', 'ORG'), ('India', 'GPE'), ('this year', 'DATE'), ('Bloomberg', 'ORG'), ('Radius', 'PERSON'), ('$48 million', 'MONEY'), ('United Parcel Service Inc.', 'ORG'), ('Plastics News', 'ORG'), ('Albertsons Cos.', 'ORG'), ('IBM Food Trust', 'ORG'), ('Supermarket News)', 'ORG'), ('Ace Hardware Corp.', 'ORG'), ('British', 'NORP'), ('Tesco PLC', 'ORG'), ('$147 million', 'MONEY'), ('the year ending in February', 'DATE'), ('Europe', 'LOC'), ('Asia', 'LOC'), ('Lloyd’s List)', 'ORG'), ('Asia', 'LOC'), ('North Europe', 'LOC'), ('36%', 'PERCENT'), ('this year', 'DATE'), ('International Container Terminal Services Inc.', 'ORG'), ('the Subic Bay', 'LOC'), ('Philippines', 'GPE'), ('Hanjin Heavy Industries', 'ORG'), ('Seatrade Maritime', 'PERSON'), ('British', 'NORP'), ('Aspray Group', 'ORG'), ('U.K.', 'GPE'), ('Motor Transport', 'ORG'), ('First-half', 'DATE'), ('U.K.', 'GPE'), ('87%', 'PERCENT'), ('first', 'ORDINAL'), ('Atlantic', 'LOC'), ('Paul Page', 'PERSON'), ('WSJ Logistics Report', 'ORG'), ('paul.page@wsj.com', 'ORG'), ('the WSJ Logistics Report', 'ORG'), ('@jensmithWSJ', 'DATE'), ('@CostasParis', 'PERSON'), ('the WSJ Logistics Report', 'ORG'), ('Twitter', 'ORG')]

# %%
doc = nlp(news_df.iloc[100]["clean_news_text"])
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('first quarter', 'DATE'), ('wsj logistics report', 'ORG'), ('costas', 'NORP'), ('paris', 'GPE'), ('35%', 'PERCENT'), ('first quarter year ago', 'DATE'), ('latin america', 'LOC'), ('china', 'GPE'), ('brazil', 'GPE'), ('fallout vale s.a.’s', 'ORG'), ('jd.com', 'PERSON'), ('chinese', 'NORP'), ('wsj', 'ORG'), ('li', 'PERSON'), ('china', 'GPE'), ('2', 'CARDINAL'), ('alibaba group holding ltd.', 'ORG'), ('recent weeks', 'DATE'), ('550', 'CARDINAL'), ('china', 'GPE'), ('nippon steel & sumitomo metal corp.', 'ORG'), ('japan', 'GPE'), ('bloomberg news', 'ORG'), ('asia', 'LOC'), ('taiwan', 'GPE'), ('china', 'GPE'), ('japanese', 'NORP'), ('apple inc.', 'ORG'), ('wsj', 'ORG'), ('takashi mochizuki', 'PERSON'), ('lifeline japan display inc.', 'ORG'), ('japan', 'GPE'), ('taiwanese', 'NORP'), ('tpk holding co.', 'ORG'), ('japan', 'GPE'), ('japan', 'GPE'), ('china', 'GPE'), ('beijing', 'GPE'), ('u.s.', 'GPE'), ('russian', 'NORP'), ('united co.', 'ORG'), ('$200 million', 'MONEY'), ('kentucky', 'GPE'), ('u.s.', 'GPE'), ('nearly four decades', 'DATE'), ('wsj', 'ORG'), ('bob tita', 'PERSON'), ('startup braidy industries', 'ORG'), ('next year', 'DATE'), ('ashland', 'GPE'), ('ky.', 'GPE'), ('10%', 'PERCENT'), ('last year', 'DATE'), ('u.s.', 'GPE'), ('one', 'CARDINAL'), ('u.s.', 'GPE'), ('year-over-year', 'DATE'), ('los angeles', 'GPE'), ('›', 'ORG'), ('u.s.', 'GPE'), ('april', 'DATE'), ('wsj', 'ORG'), ('european union', 'ORG'), ('$12 billion', 'MONEY'), ('u.s.', 'GPE'), ('boeing co.', 'ORG'), ('wsj', 'ORG'), ('india', 'GPE'), ('wsj', 'ORG'), ('bristol-myers', 'ORG'), ('$74 billion', 'MONEY'), ('drug company celgene corp.', 'ORG'), ('wsj', 'ORG'), ('merck kgaa', 'ORG'), ('versum materials inc.', 'ORG'), ('wsj', 'ORG'), ('terry gou', 'PERSON'), ('india', 'GPE'), ('3d', 'CARDINAL'), ('$48 million', 'MONEY'), ('united parcel service inc.', 'ORG'), ('plastics news', 'ORG'), ('ibm food', 'ORG'), ('supermarket news)', 'ORG'), ('ace hardware corp.', 'ORG'), ('british', 'NORP'), ('tesco plc', 'ORG'), ('$147 million', 'MONEY'), ('year ending february', 'DATE'), ('europe asia', 'LOC'), ('lloyd’s list', 'ORG'), ('asia', 'LOC'), ('north europe', 'LOC'), ('36%', 'PERCENT'), ('year', 'DATE'), ('international container terminal services inc.', 'ORG'), ('subic bay', 'PERSON'), ('philippines', 'GPE'), ('british', 'NORP'), ('u.k.', 'GPE'), ('first-half', 'DATE'), ('u.k.', 'GPE'), ('87%', 'PERCENT'), ('first', 'ORDINAL'), ('wsj logistics', 'PERSON'), ('write paul.page@wsj.com', 'ORG'), ('wsj logistics report', 'ORG'), ('@paulpage', 'ORG'), ('@jensmithwsj', 'ORG'), ('@costasparis', 'ORG'), ('wsj logistics report', 'ORG'), ('twitter @wsjlogistics', 'ORG')]

# %%
displacy.render(nlp(news_df.iloc[100]["clean_news_text"]), jupyter=True, style='ent')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-55a376fe96d8> in <module>
# ----> 1 displacy.render(nlp(news_df.iloc[100]["clean_news_text"]), jupyter=True, style='ent')
#
# NameError: name 'nlp' is not defined

# %%
displacy.render(nlp(news_df.iloc[100]["text"]), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">News and analysis on the world of logistics, from supply chain to transport and technology. Trouble viewing this email? View in web browser › The dry-bulk shipping sector at the heart of the global industrial economy is navigating stormy seas. Carriers stepped up their scrapping of the biggest bulk transport vessels in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the WSJ Logistics Report
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Costas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  writes, as shipping rates turned sharply downward in a business marked by heavy pricing volatility. Ship-broker BTIG says ship recycling was up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first quarter from a year ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and most of the scrapped capacity came in capesize vessels—the biggest ships that move iron, aluminum and coal from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latin America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The bulk sector is marked by unforgiving economics, and rates
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  are down while production in the important
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brazil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  mining market is diminished because of the fallout from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vale S.A.’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dam disaster there. Brokers expect a recovery in shipping rates as output resumes and buyers find fewer ships on the water.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JD.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s hard-charging growth plan has hit a wall. The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  e-commerce company is rolling out wide-scale layoffs and closing most of its offices abroad, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WSJ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shan Li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reports, casting a cloud over an online retail market that has become a pillar of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s domestic economic expansion.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JD.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is No.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alibaba Group Holding Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em

# %%
doc.ents[0].label_, doc.ents[0].text
# Out:
# ('DATE', 'first quarter')
